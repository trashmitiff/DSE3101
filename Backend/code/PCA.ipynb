# %%
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import seaborn as sns
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %% [markdown]
# # Commuter Hub PCA

# %%
# Read the data
data = pd.read_csv('../data/final_combined_com_v2.csv')
data = data.iloc[:,1:]
data.sort_values(by=['total_train_tap_out_volume'], inplace=True, ascending=False)
data
# Out:
#             subzone_name year_month  total_bus_tap_in_volume  \
# 580             PATERSON    2024-12             9.799845e+05
# 579             PATERSON    2024-11             9.016887e+05
# 581             PATERSON    2025-01             8.914695e+05
# 605        PEOPLE'S PARK    2025-01             2.374150e+06
# 603        PEOPLE'S PARK    2024-11             2.018887e+06
# ..                   ...        ...                      ...
# 398               KRANJI    2025-01             4.024886e+04
# 399  LAKESIDE (BUSINESS)    2024-11             4.749574e+04
# 400  LAKESIDE (BUSINESS)    2024-12             4.663459e+04
# 401  LAKESIDE (BUSINESS)    2025-01             4.809354e+04
# 944               YUNNAN    2025-01             4.886993e+05
#
#      total_bus_tap_out_volume  total_buses_per_hour  inflow_bus_score  \
# 580              4.481548e+05            463.793297      1.827038e+06
# 579              3.750948e+05            463.793297      1.507226e+06
# 581              3.835133e+05            463.793297      1.513537e+06
# 605              2.967052e+06           1457.665715      7.420988e+06
# 603              2.688093e+06           1457.665715      6.457320e+06
# ..                        ...                   ...               ...
# 398              4.629303e+04             54.771627      1.599126e+05
# 399              6.611447e+04            226.808719      2.261036e+05
# 400              6.546312e+04            226.808719      2.178863e+05
# 401              6.649281e+04            226.808719      2.203835e+05
# 944              4.722893e+05            385.287123      6.033712e+05
#
#      outflow_bus_score  total_train_tap_in_volume  total_train_tap_out_volume  \
# 580       3.228409e+06               1.300435e+07                1.371738e+07
# 579       2.878658e+06               1.120991e+07                1.185721e+07
# 581       2.837777e+06               1.118766e+07                1.181572e+07
# 605       1.013743e+07               1.028414e+07                9.819401e+06
# 603       8.373129e+06               1.023009e+07                9.781353e+06
# ..                 ...                        ...                         ...
# 398       9.175898e+04               0.000000e+00                0.000000e+00
# 399       1.161432e+05               0.000000e+00                0.000000e+00
# 400       1.145583e+05               0.000000e+00                0.000000e+00
# 401       1.161629e+05               0.000000e+00                0.000000e+00
# 944       7.713819e+05               0.000000e+00                0.000000e+00
#
#      inflow_train_score  outflow_train_score
# 580        9.187863e+07         8.851054e+07
# 579        8.022561e+07         7.685681e+07
# 581        7.845230e+07         7.463690e+07
# 605        8.890887e+07         8.528476e+07
# 603        8.913657e+07         8.558947e+07
# ..                  ...                  ...
# 398        0.000000e+00         0.000000e+00
# 399        0.000000e+00         0.000000e+00
# 400        0.000000e+00         0.000000e+00
# 401        0.000000e+00         0.000000e+00
# 944        0.000000e+00         0.000000e+00
#
# [945 rows x 11 columns]

# %%
variables = data.iloc[:,2:]
variables= variables.drop("total_buses_per_hour", axis= 1)
variables
# Out:
#      total_bus_tap_in_volume  total_bus_tap_out_volume  inflow_bus_score  \
# 580             9.799845e+05              4.481548e+05      1.827038e+06
# 579             9.016887e+05              3.750948e+05      1.507226e+06
# 581             8.914695e+05              3.835133e+05      1.513537e+06
# 605             2.374150e+06              2.967052e+06      7.420988e+06
# 603             2.018887e+06              2.688093e+06      6.457320e+06
# ..                       ...                       ...               ...
# 398             4.024886e+04              4.629303e+04      1.599126e+05
# 399             4.749574e+04              6.611447e+04      2.261036e+05
# 400             4.663459e+04              6.546312e+04      2.178863e+05
# 401             4.809354e+04              6.649281e+04      2.203835e+05
# 944             4.886993e+05              4.722893e+05      6.033712e+05
#
#      outflow_bus_score  total_train_tap_in_volume  total_train_tap_out_volume  \
# 580       3.228409e+06               1.300435e+07                1.371738e+07
# 579       2.878658e+06               1.120991e+07                1.185721e+07
# 581       2.837777e+06               1.118766e+07                1.181572e+07
# 605       1.013743e+07               1.028414e+07                9.819401e+06
# 603       8.373129e+06               1.023009e+07                9.781353e+06
# ..                 ...                        ...                         ...
# 398       9.175898e+04               0.000000e+00                0.000000e+00
# 399       1.161432e+05               0.000000e+00                0.000000e+00
# 400       1.145583e+05               0.000000e+00                0.000000e+00
# 401       1.161629e+05               0.000000e+00                0.000000e+00
# 944       7.713819e+05               0.000000e+00                0.000000e+00
#
#      inflow_train_score  outflow_train_score
# 580        9.187863e+07         8.851054e+07
# 579        8.022561e+07         7.685681e+07
# 581        7.845230e+07         7.463690e+07
# 605        8.890887e+07         8.528476e+07
# 603        8.913657e+07         8.558947e+07
# ..                  ...                  ...
# 398        0.000000e+00         0.000000e+00
# 399        0.000000e+00         0.000000e+00
# 400        0.000000e+00         0.000000e+00
# 401        0.000000e+00         0.000000e+00
# 944        0.000000e+00         0.000000e+00
#
# [945 rows x 8 columns]

# %%
# Standardize the data
scaler = StandardScaler()
normalized_data = scaler.fit_transform(variables)

# %%
# PCA
pca =PCA(n_components=5)
transformed_data = pca.fit_transform(normalized_data)

explained_variance_ratios = pca.explained_variance_ratio_
print(explained_variance_ratios)
print(transformed_data)
# Out:
# [0.7067803  0.26312911 0.01500278 0.00995105 0.00334401]
# [[ 1.41066792e+01  1.11201611e+01 -2.00476060e-02  4.12420608e-01
#    8.79437568e-01]
#  [ 1.20623966e+01  9.69277302e+00 -1.65193583e-02  4.62954852e-01
#    7.16137546e-01]
#  [ 1.18942304e+01  9.55217836e+00 -1.33823158e-02  4.49796123e-01
#    8.70950091e-01]
#  ...
#  [-1.28382955e+00  4.34909654e-01  9.59121312e-02 -4.84540706e-02
#   -1.93199859e-02]
#  [-1.28113242e+00  4.32011113e-01  9.47524158e-02 -4.83944495e-02
#   -1.89181532e-02]
#  [-4.51124277e-01 -4.60865014e-01 -3.81088915e-01  2.04315767e-01
#    2.49074129e-02]]

# %%
# Feature importance
first_pc_loadings = pca.components_[0]
print(first_pc_loadings)
# Out:
# [0.34528351 0.33744023 0.34206077 0.35109658 0.36013724 0.36036132
#  0.36514928 0.36571288]

# %%
weights = np.abs(pca.components_) / np.sum(np.abs(pca.components_), axis=1, keepdims=True)
tryweights = weights[:1]
tryweights
# Out:
# array([[0.12212733, 0.11935316, 0.12098745, 0.12418343, 0.12738113,
#         0.12746038, 0.12915389, 0.12935324]])

# %%
coefficient_dict = dict(zip(variables.columns, tryweights[0]))
coefficient_dict
# Out:
# {'total_bus_tap_in_volume': 0.12212733488665704,
#  'total_bus_tap_out_volume': 0.1193531555713314,
#  'inflow_bus_score': 0.12098744670609606,
#  'outflow_bus_score': 0.12418342782131626,
#  'total_train_tap_in_volume': 0.12738112532184728,
#  'total_train_tap_out_volume': 0.12746038084960107,
#  'inflow_train_score': 0.12915389067706173,
#  'outflow_train_score': 0.1293532381660892}

# %%
normalized_variables = variables
normalized_variables[:] = normalized_data
normalized_variables
# Out:
#      total_bus_tap_in_volume  total_bus_tap_out_volume  inflow_bus_score  \
# 580                 1.242870                  0.169326          0.584391
# 579                 1.082552                  0.014292          0.362440
# 581                 1.061627                  0.032156          0.366820
# 605                 4.097554                  5.514430          4.466612
# 603                 3.370120                  4.922478          3.797823
# ..                       ...                       ...               ...
# 398                -0.681326                 -0.683426         -0.572600
# 399                -0.666487                 -0.641365         -0.526664
# 400                -0.668251                 -0.642747         -0.532367
# 401                -0.665263                 -0.640562         -0.530633
# 944                 0.236918                  0.220539         -0.264839
#
#      outflow_bus_score  total_train_tap_in_volume  total_train_tap_out_volume  \
# 580           1.304182                   9.223465                    9.488454
# 579           1.095875                   7.906810                    8.159089
# 581           1.071526                   7.890479                    8.129442
# 605           5.419098                   7.227528                    6.702781
# 603           4.368307                   7.187871                    6.675589
# ..                 ...                        ...                         ...
# 398          -0.563964                  -0.318385                   -0.314611
# 399          -0.549441                  -0.318385                   -0.314611
# 400          -0.550385                  -0.318385                   -0.314611
# 401          -0.549430                  -0.318385                   -0.314611
# 944          -0.159190                  -0.318385                   -0.314611
#
#      inflow_train_score  outflow_train_score
# 580            8.463620             8.561741
# 579            7.350208             7.392063
# 581            7.180772             7.169251
# 605            8.179868             8.237971
# 603            8.201624             8.268555
# ..                  ...                  ...
# 398           -0.315119            -0.322011
# 399           -0.315119            -0.322011
# 400           -0.315119            -0.322011
# 401           -0.315119            -0.322011
# 944           -0.315119            -0.322011
#
# [945 rows x 8 columns]

# %%
# Multiply each column by the corresponding coefficient
for column_name, coefficient in coefficient_dict.items():
    normalized_variables[column_name] = normalized_variables[column_name] * coefficient

normalized_variables['commuter_score'] = normalized_variables.sum(axis=1)
normalized_variables = pd.concat([data.iloc[:,0:2],normalized_variables],axis=1)
normalized_variables
# Out:
#             subzone_name year_month  total_bus_tap_in_volume  \
# 580             PATERSON    2024-12                 0.151788
# 579             PATERSON    2024-11                 0.132209
# 581             PATERSON    2025-01                 0.129654
# 605        PEOPLE'S PARK    2025-01                 0.500423
# 603        PEOPLE'S PARK    2024-11                 0.411584
# ..                   ...        ...                      ...
# 398               KRANJI    2025-01                -0.083209
# 399  LAKESIDE (BUSINESS)    2024-11                -0.081396
# 400  LAKESIDE (BUSINESS)    2024-12                -0.081612
# 401  LAKESIDE (BUSINESS)    2025-01                -0.081247
# 944               YUNNAN    2025-01                 0.028934
#
#      total_bus_tap_out_volume  inflow_bus_score  outflow_bus_score  \
# 580                  0.020210          0.070704           0.161958
# 579                  0.001706          0.043851           0.136089
# 581                  0.003838          0.044381           0.133066
# 605                  0.658165          0.540404           0.672962
# 603                  0.587513          0.459489           0.542471
# ..                        ...               ...                ...
# 398                 -0.081569         -0.069277          -0.070035
# 399                 -0.076549         -0.063720          -0.068232
# 400                 -0.076714         -0.064410          -0.068349
# 401                 -0.076453         -0.064200          -0.068230
# 944                  0.026322         -0.032042          -0.019769
#
#      total_train_tap_in_volume  total_train_tap_out_volume  \
# 580                   1.174895                    1.209402
# 579                   1.007178                    1.039961
# 581                   1.005098                    1.036182
# 605                   0.920651                    0.854339
# 603                   0.915599                    0.850873
# ..                         ...                         ...
# 398                  -0.040556                   -0.040100
# 399                  -0.040556                   -0.040100
# 400                  -0.040556                   -0.040100
# 401                  -0.040556                   -0.040100
# 944                  -0.040556                   -0.040100
#
#      inflow_train_score  outflow_train_score  commuter_score
# 580            1.093109             1.107489        4.989555
# 579            0.949308             0.956187        4.266489
# 581            0.927425             0.927366        4.207009
# 605            1.056462             1.065608        6.269014
# 603            1.059272             1.069564        5.896366
# ..                  ...                  ...             ...
# 398           -0.040699            -0.041653       -0.467099
# 399           -0.040699            -0.041653       -0.452905
# 400           -0.040699            -0.041653       -0.454093
# 401           -0.040699            -0.041653       -0.453139
# 944           -0.040699            -0.041653       -0.159563
#
# [945 rows x 11 columns]

# %%
subzone_data = pd.read_csv("../data/subzone_final.csv", index_col = 0)
subzone_data=subzone_data.loc[:,['subzone_name','planning_area_name']]
subzone_data
# Out:
#             subzone_name planning_area_name
# 0             DEPOT ROAD        BUKIT MERAH
# 1            BUKIT MERAH        BUKIT MERAH
# 2              CHINATOWN             OUTRAM
# 3                PHILLIP      DOWNTOWN CORE
# 4          RAFFLES PLACE      DOWNTOWN CORE
# ..                   ...                ...
# 327        UPPER THOMSON             BISHAN
# 328           SHANGRI-LA         ANG MO KIO
# 329           TOWNSVILLE         ANG MO KIO
# 330            MARYMOUNT             BISHAN
# 331  TUAS VIEW EXTENSION               TUAS
#
# [332 rows x 2 columns]

# %%
# Normalize the total column and display final commuter hub ranking
scaler=MinMaxScaler()
normalized_variables['relative_commuter_score'] = normalized_variables.groupby("year_month")['commuter_score'].transform(lambda x: scaler.fit_transform(x.values.reshape(-1,1)).flatten())
final_com_pca = normalized_variables.sort_values(by='commuter_score',ascending=False)
final_com_pca=final_com_pca.merge(subzone_data, how='left', on='subzone_name')
col_to_move = final_com_pca.pop("planning_area_name")  # Remove column
final_com_pca.insert(0, "planning_area_name", col_to_move)  # Insert at position 0
final_com_pca[(final_com_pca['year_month']=='2025-01')].head(50)
# Out:
#     planning_area_name               subzone_name year_month  \
# 0               OUTRAM              PEOPLE'S PARK    2025-01
# 4            WOODLANDS  WOODLANDS REGIONAL CENTRE    2025-01
# 6               ROCHOR                FARRER PARK    2025-01
# 11        RIVER VALLEY                   PATERSON    2025-01
# 12              ROCHOR                   VICTORIA    2025-01
# 15              YISHUN             YISHUN CENTRAL    2025-01
# 20              MUSEUM                DHOBY GHAUT    2025-01
# 22              NEWTON              NEWTON CIRCUS    2025-01
# 23       DOWNTOWN CORE              RAFFLES PLACE    2025-01
# 28       DOWNTOWN CORE              TANJONG PAGAR    2025-01
# 31         JURONG EAST             JURONG GATEWAY    2025-01
# 34          ANG MO KIO     ANG MO KIO TOWN CENTRE    2025-01
# 36             HOUGANG            HOUGANG CENTRAL    2025-01
# 37             ORCHARD                   SOMERSET    2025-01
# 42            CLEMENTI           CLEMENTI CENTRAL    2025-01
# 43              ROCHOR                SUNGEI ROAD    2025-01
# 46         JURONG WEST        JURONG WEST CENTRAL    2025-01
# 47              OUTRAM                  CHINATOWN    2025-01
# 50         BUKIT MERAH        TIONG BAHRU STATION    2025-01
# 57       BUKIT PANJANG                     JELEBU    2025-01
# 59              ROCHOR                  MACKENZIE    2025-01
# 60              ROCHOR                  BENCOOLEN    2025-01
# 63              MUSEUM                 BRAS BASAH    2025-01
# 68             ORCHARD                  BOULEVARD    2025-01
# 70           SERANGOON          SERANGOON CENTRAL    2025-01
# 76       DOWNTOWN CORE                      BUGIS    2025-01
# 78           TOA PAYOH          TOA PAYOH CENTRAL    2025-01
# 79         BUKIT BATOK        BUKIT BATOK CENTRAL    2025-01
# 80       DOWNTOWN CORE                  CITY HALL    2025-01
# 85       CHOA CHU KANG      CHOA CHU KANG CENTRAL    2025-01
# 87            SENGKANG       SENGKANG TOWN CENTRE    2025-01
# 90     SINGAPORE RIVER                CLARKE QUAY    2025-01
# 96         BUKIT MERAH                    REDHILL    2025-01
# 97           SEMBAWANG          SEMBAWANG CENTRAL    2025-01
# 99              YISHUN                YISHUN WEST    2025-01
# 100         ANG MO KIO                  CHENG SAN    2025-01
# 104             ROCHOR                    SELEGIE    2025-01
# 108         QUEENSTOWN               COMMONWEALTH    2025-01
# 114             OUTRAM               CHINA SQUARE    2025-01
# 115            PUNGGOL                    MATILDA    2025-01
# 117           TAMPINES              TAMPINES EAST    2025-01
# 120            KALLANG                  BOON KENG    2025-01
# 124      DOWNTOWN CORE                      CECIL    2025-01
# 127      DOWNTOWN CORE           BAYFRONT SUBZONE    2025-01
# 130            KALLANG                   LAVENDER    2025-01
# 135          PASIR RIS          PASIR RIS CENTRAL    2025-01
# 137              BEDOK                BEDOK NORTH    2025-01
# 138             YISHUN                     KHATIB    2025-01
# 139           SENGKANG                  RIVERVALE    2025-01
# 143            KALLANG                   CRAWFORD    2025-01
#
#      total_bus_tap_in_volume  total_bus_tap_out_volume  inflow_bus_score  \
# 0                   0.500423                  0.658165          0.540404
# 4                   0.903086                  0.766328          0.981356
# 6                   0.403833                  0.349685          0.452188
# 11                  0.129654                  0.003838          0.044381
# 12                  0.332973                  0.275191          0.340281
# 15                  0.752486                  0.818695          0.664393
# 20                  0.221975                  0.277762          0.471272
# 22                  0.133753                  0.062349          0.049239
# 23                 -0.030822                 -0.052602         -0.035335
# 28                 -0.052577                 -0.057734          0.011107
# 31                  0.240648                  0.266952          0.202046
# 34                  0.670642                  0.646930          0.497014
# 36                  0.398767                  0.452096          0.293107
# 37                  0.248140                  0.194655          0.325730
# 42                  0.364683                  0.302074          0.238446
# 43                  0.186584                  0.215342          0.325359
# 46                  0.368076                  0.357603          0.181869
# 47                  0.084219                  0.048986          0.080795
# 50                  0.372841                  0.332704          0.116739
# 57                  0.224129                  0.210913          0.278460
# 59                  0.393442                  0.155701          0.165286
# 60                  0.048584                  0.062662          0.096889
# 63                  0.219122                  0.228341          0.329151
# 68                  0.240311                  0.272982          0.483168
# 70                  0.227098                  0.191953          0.144344
# 76                  0.236222                  0.244721          0.371851
# 78                  0.216885                  0.209033          0.174477
# 79                  0.227920                  0.206924          0.132009
# 80                  0.018910                  0.028551          0.065236
# 85                  0.176461                  0.153460          0.125387
# 87                  0.164547                  0.155203          0.139184
# 90                  0.074796                  0.013099         -0.005878
# 96                  0.120503                  0.108982          0.049946
# 97                  0.118737                  0.108029          0.028310
# 99                  0.114065                  0.095358          0.110089
# 100                 0.122904                  0.092789          0.027465
# 104                 0.199703                  0.199936          0.115815
# 108                 0.117869                  0.063803          0.013085
# 114                 0.140801                  0.167206          0.271345
# 115                 0.100817                  0.111562          0.076765
# 117                 0.141189                  0.141486          0.103631
# 120                 0.104251                  0.101560          0.069107
# 124                 0.075712                  0.086970          0.285005
# 127                -0.049899                 -0.047237         -0.026264
# 130                 0.089264                  0.075865          0.080864
# 135                 0.088073                  0.097734          0.046810
# 137                 0.119355                  0.119944          0.055963
# 138                -0.017159                  0.049894          0.176753
# 139                 0.059829                  0.069053          0.155062
# 143                 0.101321                  0.120724          0.116781
#
#      outflow_bus_score  total_train_tap_in_volume  total_train_tap_out_volume  \
# 0             0.672962                   0.920651                    0.854339
# 4             0.929448                   0.209783                    0.251952
# 6             0.477466                   0.722005                    0.763435
# 11            0.133066                   1.005098                    1.036182
# 12            0.547431                   0.681440                    0.693205
# 15            0.761931                  -0.040556                   -0.040100
# 20            0.384633                   0.367886                    0.333593
# 22            0.074624                   0.667710                    0.679050
# 23            0.003403                   0.657058                    0.639738
# 28           -0.038258                   0.566328                    0.570096
# 31            0.174552                   0.297143                    0.289788
# 34            0.450752                  -0.040556                   -0.040100
# 36            0.218421                   0.153351                    0.142846
# 37            0.357083                   0.221160                    0.225483
# 42            0.253156                   0.128968                    0.133913
# 43            0.162993                   0.206842                    0.216300
# 46            0.172574                   0.105473                    0.103969
# 47            0.075264                   0.334096                    0.327119
# 50            0.113977                   0.147991                    0.153198
# 57            0.201530                   0.092956                    0.094675
# 59            0.779576                  -0.040556                   -0.040100
# 60            0.131986                   0.254955                    0.253799
# 63            0.374005                   0.021340                    0.024109
# 68            0.355703                  -0.040556                   -0.040100
# 70            0.144157                   0.106494                    0.107283
# 76            0.208704                  -0.040556                   -0.040100
# 78            0.133289                   0.045743                    0.047432
# 79            0.083825                   0.051735                    0.055172
# 80            0.038857                   0.173276                    0.166365
# 85            0.127863                   0.057305                    0.061481
# 87            0.151369                   0.049471                    0.050320
# 90            0.102407                   0.143234                    0.152723
# 96            0.028383                   0.082237                    0.083808
# 97            0.035840                   0.071598                    0.069571
# 99            0.044373                   0.048453                    0.052754
# 100           0.034755                   0.077865                    0.086894
# 104           0.242208                  -0.040556                   -0.040100
# 108           0.068664                   0.072773                    0.069805
# 114           0.112353                  -0.040556                   -0.040100
# 115           0.060159                   0.050211                    0.046753
# 117           0.090997                   0.003805                    0.002933
# 120           0.051114                   0.040230                    0.039403
# 124           0.172135                  -0.040556                   -0.040100
# 127          -0.015190                   0.170789                    0.150596
# 130           0.070481                   0.021490                    0.023063
# 135           0.028965                   0.010715                    0.008832
# 137           0.047656                  -0.013574                   -0.013565
# 138          -0.038264                   0.025123                    0.017210
# 139           0.069617                  -0.019039                   -0.019857
# 143           0.081700                  -0.040556                   -0.040100
#
#      inflow_train_score  outflow_train_score  commuter_score  \
# 0              1.056462             1.065608        6.269014
# 4              0.349719             0.298812        4.690485
# 6              0.702982             0.706923        4.578516
# 11             0.927425             0.927366        4.207009
# 12             0.655852             0.679994        4.206367
# 15            -0.040699            -0.041653        2.834497
# 20             0.256357             0.315982        2.629460
# 22             0.480848             0.459682        2.607255
# 23             0.713405             0.686582        2.581427
# 28             0.718372             0.692875        2.410208
# 31             0.336253             0.344126        2.151508
# 34            -0.040699            -0.041653        2.102330
# 36             0.141365             0.158521        1.958474
# 37             0.180300             0.195064        1.947615
# 42             0.170135             0.166791        1.758166
# 43             0.191717             0.187039        1.692177
# 46             0.164243             0.174978        1.628785
# 47             0.328017             0.347251        1.625748
# 50             0.151423             0.152147        1.541020
# 57             0.111391             0.122708        1.336764
# 59            -0.040699            -0.041653        1.330996
# 60             0.219144             0.223109        1.291128
# 63             0.019705             0.011819        1.227593
# 68            -0.040699            -0.041653        1.189155
# 70             0.087144             0.088587        1.097059
# 76            -0.040699            -0.041653        0.898489
# 78             0.029657             0.029131        0.885649
# 79             0.059929             0.059553        0.877068
# 80             0.172996             0.187328        0.851517
# 85             0.058774             0.056249        0.816978
# 87             0.042918             0.040239        0.793251
# 90             0.138454             0.133965        0.752800
# 96             0.097187             0.093193        0.664239
# 97             0.109021             0.119525        0.660631
# 99             0.086947             0.082410        0.634449
# 100            0.096147             0.089821        0.628641
# 104           -0.040699            -0.041653        0.594653
# 108            0.080238             0.081903        0.568140
# 114           -0.040699            -0.041653        0.528696
# 115            0.040036             0.042052        0.528354
# 117            0.008375             0.010027        0.502443
# 120            0.039688             0.042109        0.487463
# 124           -0.040699            -0.041653        0.456814
# 127            0.117641             0.137127        0.437563
# 130            0.027082             0.024258        0.412367
# 135            0.021922             0.028097        0.331147
# 137           -0.007768            -0.007272        0.300739
# 138            0.033220             0.044036        0.290812
# 139           -0.025998            -0.023810        0.264858
# 143           -0.040699            -0.041653        0.257518
#
#      relative_commuter_score
# 0                   1.000000
# 4                   0.767111
# 6                   0.750592
# 11                  0.695782
# 12                  0.695687
# 15                  0.493288
# 20                  0.463038
# 22                  0.459762
# 23                  0.455951
# 28                  0.430690
# 31                  0.392523
# 34                  0.385268
# 36                  0.364044
# 37                  0.362442
# 42                  0.334491
# 43                  0.324756
# 46                  0.315403
# 47                  0.314955
# 50                  0.302455
# 57                  0.272320
# 59                  0.271469
# 60                  0.265587
# 63                  0.256213
# 68                  0.250542
# 70                  0.236955
# 76                  0.207659
# 78                  0.205764
# 79                  0.204498
# 80                  0.200729
# 85                  0.195633
# 87                  0.192132
# 90                  0.186164
# 96                  0.173099
# 97                  0.172566
# 99                  0.168703
# 100                 0.167847
# 104                 0.162832
# 108                 0.158921
# 114                 0.153101
# 115                 0.153051
# 117                 0.149228
# 120                 0.147018
# 124                 0.142496
# 127                 0.139656
# 130                 0.135939
# 135                 0.123956
# 137                 0.119470
# 138                 0.118005
# 139                 0.114176
# 143                 0.113093

# %%
# Save the final score
final_com_pca.to_csv('../data/final_combined_com_pca.csv')

# %% [markdown]
# ### Future Commuter Hub Score

# %%
predicted_growth= pd.read_csv("../data/Population_growth.csv").iloc[:,1:]
predicted_growth['Subzone']= predicted_growth['Subzone'].str.upper()
predicted_growth
# Out:
#              Subzone  2025      2026      2027      2028      2029      2030  \
# 0          ADMIRALTY   1.0  1.006169  1.012339  1.018508  1.024678  1.030847
# 1       AIRPORT ROAD   NaN       NaN       NaN       NaN       NaN       NaN
# 2     ALEXANDRA HILL   1.0  0.974991  0.949982  0.924973  0.899963  0.874954
# 3    ALEXANDRA NORTH   1.0  1.061637  1.123275  1.184912  1.246550  1.308187
# 4           ALJUNIED   1.0  0.999120  0.998240  0.997360  0.996481  0.995601
# ..               ...   ...       ...       ...       ...       ...       ...
# 291     YISHUN SOUTH   1.0  1.005640  1.011280  1.016920  1.022560  1.028200
# 292      YISHUN WEST   1.0  0.985696  0.971392  0.957087  0.942783  0.928479
# 293       YUHUA EAST   1.0  0.979079  0.958159  0.937238  0.916318  0.895397
# 294       YUHUA WEST   1.0  0.990607  0.981215  0.971822  0.962429  0.953037
# 295           YUNNAN   1.0  0.990613  0.981226  0.971839  0.962453  0.953066
#
#          2031      2032      2033      2034      2035
# 0    1.037016  1.043186  1.049355  1.055524  1.061694
# 1         NaN       NaN       NaN       NaN       NaN
# 2    0.849945  0.824936  0.799927  0.774918  0.749908
# 3    1.369825  1.431462  1.493100  1.554737  1.616375
# 4    0.994721  0.993841  0.992961  0.992081  0.991201
# ..        ...       ...       ...       ...       ...
# 291  1.033840  1.039480  1.045120  1.050760  1.056400
# 292  0.914175  0.899870  0.885566  0.871262  0.856958
# 293  0.874477  0.853556  0.832636  0.811715  0.790795
# 294  0.943644  0.934251  0.924859  0.915466  0.906074
# 295  0.943679  0.934292  0.924905  0.915518  0.906132
#
# [296 rows x 12 columns]

# %%
future_com_hub_score = final_com_pca.groupby(['planning_area_name','subzone_name']).agg({'commuter_score':'mean'}).reset_index()

# %%
future_com_hub_score= future_com_hub_score.merge(predicted_growth, how='left', left_on='subzone_name',right_on='Subzone').drop('Subzone',axis=1)
future_com_hub_score[future_com_hub_score.isnull().any(axis=1)]
# Out:
#           planning_area_name         subzone_name  commuter_score  2025  2026  \
# 10                ANG MO KIO   YIO CHU KANG NORTH       -0.443676   NaN   NaN
# 72                CHANGI BAY           CHANGI BAY       -0.505535   NaN   NaN
# 89             DOWNTOWN CORE     BAYFRONT SUBZONE        0.434588   NaN   NaN
# 96             DOWNTOWN CORE              MAXWELL       -0.195586   NaN   NaN
# 97             DOWNTOWN CORE               NICOLL       -0.353834   NaN   NaN
# 113                  HOUGANG         LORONG HALUS       -0.507154   NaN   NaN
# 120              JURONG EAST  LAKESIDE (BUSINESS)       -0.453379   NaN   NaN
# 121              JURONG EAST   LAKESIDE (LEISURE)       -0.375522   NaN   NaN
# 132              JURONG WEST                SAFTI       -0.498046   NaN   NaN
# 146                   MANDAI          MANDAI EAST       -0.498862   NaN   NaN
# 148                   MANDAI          MANDAI WEST       -0.506206   NaN   NaN
# 149             MARINA SOUTH         MARINA SOUTH       -0.482600   NaN   NaN
# 150            MARINE PARADE           EAST COAST       -0.505944   NaN   NaN
# 152            MARINE PARADE     MARINA EAST (MP)       -0.509040   NaN   NaN
# 183               PAYA LEBAR         AIRPORT ROAD       -0.462741   NaN   NaN
# 187               PAYA LEBAR                 PLAB       -0.504109   NaN   NaN
# 195                  PUNGGOL        PUNGGOL CANAL       -0.500060   NaN   NaN
# 238                SEMBAWANG          THE WHARVES       -0.490484   NaN   NaN
# 256             STRAITS VIEW         STRAITS VIEW       -0.479528   NaN   NaN
# 271                   TENGAH            BRICKLAND       -0.488491   NaN   NaN
# 272                   TENGAH          FOREST HILL       -0.505708   NaN   NaN
# 273                   TENGAH               GARDEN       -0.459164   NaN   NaN
# 274                   TENGAH                 PARK       -0.486074   NaN   NaN
# 275                   TENGAH           PLANTATION       -0.369972   NaN   NaN
# 288                     TUAS               TENGEH       -0.506541   NaN   NaN
# 294  WESTERN WATER CATCHMENT                BAHAR       -0.504186   NaN   NaN
# 295  WESTERN WATER CATCHMENT            CLEANTECH       -0.486835   NaN   NaN
# 296  WESTERN WATER CATCHMENT                MURAI       -0.501714   NaN   NaN
#
#      2027  2028  2029  2030  2031  2032  2033  2034  2035
# 10    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 72    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 89    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 96    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 97    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 113   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 120   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 121   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 132   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 146   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 148   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 149   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 150   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 152   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 183   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 187   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 195   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 238   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 256   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 271   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 272   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 273   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 274   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 275   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 288   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 294   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 295   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 296   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN

# %%
future_com_hub_score['2025']= future_com_hub_score['2025'].fillna(1)
future_com_hub_score.iloc[:,3:]= future_com_hub_score.iloc[:,3:].mul(future_com_hub_score['commuter_score'],axis=0)
future_com_hub_score
# Out:
#     planning_area_name            subzone_name  commuter_score      2025  \
# 0           ANG MO KIO  ANG MO KIO TOWN CENTRE        1.982747  1.982747
# 1           ANG MO KIO               CHENG SAN        0.597564  0.597564
# 2           ANG MO KIO              CHONG BOON       -0.024528 -0.024528
# 3           ANG MO KIO             KEBUN BAHRU       -0.167156 -0.167156
# 4           ANG MO KIO         SEMBAWANG HILLS       -0.410443 -0.410443
# ..                 ...                     ...             ...       ...
# 310             YISHUN              SPRINGLEAF       -0.471914 -0.471914
# 311             YISHUN          YISHUN CENTRAL        2.786927  2.786927
# 312             YISHUN             YISHUN EAST       -0.123112 -0.123112
# 313             YISHUN            YISHUN SOUTH       -0.024147 -0.024147
# 314             YISHUN             YISHUN WEST        0.595767  0.595767
#
#          2026      2027      2028      2029      2030      2031      2032  \
# 0    1.980232  1.977717  1.975202  1.972686  1.970171  1.967656  1.965141
# 1    0.590216  0.582868  0.575520  0.568173  0.560825  0.553477  0.546130
# 2   -0.024180 -0.023832 -0.023484 -0.023136 -0.022788 -0.022440 -0.022092
# 3   -0.164856 -0.162556 -0.160256 -0.157956 -0.155657 -0.153357 -0.151057
# 4   -0.410235 -0.410026 -0.409817 -0.409609 -0.409400 -0.409192 -0.408983
# ..        ...       ...       ...       ...       ...       ...       ...
# 310 -0.477539 -0.483163 -0.488788 -0.494412 -0.500037 -0.505661 -0.511286
# 311  2.909802  3.032677  3.155551  3.278426  3.401301  3.524176  3.647051
# 312 -0.127570 -0.132029 -0.136487 -0.140945 -0.145404 -0.149862 -0.154320
# 313 -0.024283 -0.024419 -0.024556 -0.024692 -0.024828 -0.024964 -0.025100
# 314  0.587245  0.578723  0.570201  0.561679  0.553157  0.544635  0.536113
#
#          2033      2034      2035
# 0    1.962625  1.960110  1.957595
# 1    0.538782  0.531434  0.524086
# 2   -0.021744 -0.021396 -0.021048
# 3   -0.148757 -0.146457 -0.144157
# 4   -0.408774 -0.408566 -0.408357
# ..        ...       ...       ...
# 310 -0.516910 -0.522535 -0.528159
# 311  3.769925  3.892800  4.015675
# 312 -0.158778 -0.163237 -0.167695
# 313 -0.025236 -0.025373 -0.025509
# 314  0.527591  0.519069  0.510547
#
# [315 rows x 14 columns]

# %%
baseline_mean = future_com_hub_score.iloc[:, 3:].mean() 
baseline_std = future_com_hub_score.iloc[:, 3:].std()
future_com_hub_score_scaled=future_com_hub_score
future_com_hub_score_scaled.iloc[:,3:] = (future_com_hub_score.iloc[:, 3:] - baseline_mean) / baseline_std


scaler=MinMaxScaler()
future_com_hub_score_scaled.iloc[:,3:]=scaler.fit_transform(future_com_hub_score_scaled.iloc[:,3:])

# %%
future_com_hub_score_scaled.sort_values(by='2025',ascending=False).head(20)
# Out:
#     planning_area_name               subzone_name  commuter_score      2025  \
# 174             OUTRAM              PEOPLE'S PARK        5.969904  1.000000
# 303          WOODLANDS  WOODLANDS REGIONAL CENTRE        4.645747  0.795622
# 218       RIVER VALLEY                   PATERSON        4.487684  0.771225
# 220             ROCHOR                FARRER PARK        4.283471  0.739706
# 227             ROCHOR                   VICTORIA        4.123682  0.715043
# 311             YISHUN             YISHUN CENTRAL        2.786927  0.508720
# 156             MUSEUM                DHOBY GHAUT        2.672248  0.491019
# 161             NEWTON              NEWTON CIRCUS        2.554839  0.472898
# 99       DOWNTOWN CORE              RAFFLES PLACE        2.537565  0.470232
# 100      DOWNTOWN CORE              TANJONG PAGAR        2.407386  0.450139
# 117        JURONG EAST             JURONG GATEWAY        2.135282  0.408141
# 169            ORCHARD                   SOMERSET        2.071248  0.398257
# 0           ANG MO KIO     ANG MO KIO TOWN CENTRE        1.982747  0.384598
# 107            HOUGANG            HOUGANG CENTRAL        1.849045  0.363961
# 79            CLEMENTI           CLEMENTI CENTRAL        1.660458  0.334854
# 226             ROCHOR                SUNGEI ROAD        1.623278  0.329115
# 130        JURONG WEST        JURONG WEST CENTRAL        1.548578  0.317585
# 52         BUKIT MERAH        TIONG BAHRU STATION        1.464449  0.304600
# 172             OUTRAM                  CHINATOWN        1.447684  0.302013
# 168            ORCHARD                  BOULEVARD        1.270105  0.274604
#
#          2026      2027      2028      2029      2030      2031      2032  \
# 174  1.000000  1.000000  0.960466  0.912640  0.876818  0.848985  0.826736
# 303  0.879201  0.942507  0.952743  0.941532  0.933134  0.926609  0.921394
# 218  0.886186  0.973193  1.000000  1.000000  1.000000  1.000000  1.000000
# 220  0.811938  0.866756  0.873620  0.861491  0.852407  0.845348  0.839706
# 227  0.791246  0.849092  0.858924  0.849260  0.842021  0.836397  0.831901
# 311  0.648400  0.754391  0.804091  0.824710  0.840154  0.852154  0.861747
# 156  0.635702  0.745488  0.798388  0.821464  0.838747  0.852177  0.862912
# 161  0.612280  0.718092  0.769093  0.791353  0.808026  0.820981  0.831336
# 99   0.563485  0.634506  0.662708  0.670355  0.676082  0.680532  0.684089
# 100  0.594228  0.703619  0.757878  0.782745  0.801370  0.815842  0.827410
# 117  0.567960  0.689271  0.753040  0.784969  0.808884  0.827466  0.842320
# 169  0.543795  0.654347  0.711424  0.739268  0.760123  0.776327  0.789280
# 0    0.524810  0.631362  0.686347  0.713151  0.733227  0.748826  0.761295
# 107  0.505686  0.613405  0.669975  0.698262  0.719449  0.735911  0.749070
# 79   0.483552  0.596569  0.657780  0.689706  0.713618  0.732198  0.747051
# 226  0.471188  0.579215  0.637368  0.667454  0.689989  0.707499  0.721495
# 130  0.465032  0.577127  0.638415  0.670777  0.695017  0.713851  0.728907
# 52   0.453347  0.566439  0.628898  0.662305  0.687327  0.706769  0.722310
# 172  0.451154  0.564548  0.627307  0.660966  0.686177  0.705765  0.721423
# 168  0.433963  0.555099  0.624040  0.662292  0.690943  0.713205  0.731000
#
#          2033      2034      2035
# 174  0.808544  0.793393  0.780578
# 303  0.917129  0.913577  0.910573
# 218  1.000000  1.000000  1.000000
# 220  0.835093  0.831250  0.828000
# 227  0.828224  0.825163  0.822573
# 311  0.869590  0.876122  0.881647
# 156  0.871689  0.879000  0.885183
# 161  0.839803  0.846855  0.852820
# 99   0.686998  0.689420  0.691469
# 100  0.836869  0.844747  0.851410
# 117  0.854465  0.864581  0.873136
# 169  0.799872  0.808693  0.816154
# 0    0.771490  0.779982  0.787164
# 107  0.759830  0.768791  0.776371
# 79   0.759194  0.769309  0.777864
# 226  0.732939  0.742471  0.750533
# 130  0.741217  0.751470  0.760141
# 52   0.735018  0.745602  0.754553
# 172  0.734226  0.744890  0.753909
# 168  0.745551  0.757669  0.767919

# %%
future_com_hub_score_scaled.sort_values(by='2035',ascending=False).head(20)
# Out:
#     planning_area_name               subzone_name  commuter_score      2025  \
# 218       RIVER VALLEY                   PATERSON        4.487684  0.771225
# 303          WOODLANDS  WOODLANDS REGIONAL CENTRE        4.645747  0.795622
# 156             MUSEUM                DHOBY GHAUT        2.672248  0.491019
# 311             YISHUN             YISHUN CENTRAL        2.786927  0.508720
# 117        JURONG EAST             JURONG GATEWAY        2.135282  0.408141
# 161             NEWTON              NEWTON CIRCUS        2.554839  0.472898
# 100      DOWNTOWN CORE              TANJONG PAGAR        2.407386  0.450139
# 220             ROCHOR                FARRER PARK        4.283471  0.739706
# 227             ROCHOR                   VICTORIA        4.123682  0.715043
# 258       SUNGEI KADUT                     KRANJI       -0.467046  0.006482
# 169            ORCHARD                   SOMERSET        2.071248  0.398257
# 0           ANG MO KIO     ANG MO KIO TOWN CENTRE        1.982747  0.384598
# 174             OUTRAM              PEOPLE'S PARK        5.969904  1.000000
# 79            CLEMENTI           CLEMENTI CENTRAL        1.660458  0.334854
# 107            HOUGANG            HOUGANG CENTRAL        1.849045  0.363961
# 223             ROCHOR                  MACKENZIE        1.205052  0.264563
# 168            ORCHARD                  BOULEVARD        1.270105  0.274604
# 155             MUSEUM                 BRAS BASAH        1.192173  0.262576
# 181          PASIR RIS   PASIR RIS WAFER FAB PARK       -0.494683  0.002216
# 130        JURONG WEST        JURONG WEST CENTRAL        1.548578  0.317585
#
#          2026      2027      2028      2029      2030      2031      2032  \
# 218  0.886186  0.973193  1.000000  1.000000  1.000000  1.000000  1.000000
# 303  0.879201  0.942507  0.952743  0.941532  0.933134  0.926609  0.921394
# 156  0.635702  0.745488  0.798388  0.821464  0.838747  0.852177  0.862912
# 311  0.648400  0.754391  0.804091  0.824710  0.840154  0.852154  0.861747
# 117  0.567960  0.689271  0.753040  0.784969  0.808884  0.827466  0.842320
# 161  0.612280  0.718092  0.769093  0.791353  0.808026  0.820981  0.831336
# 100  0.594228  0.703619  0.757878  0.782745  0.801370  0.815842  0.827410
# 220  0.811938  0.866756  0.873620  0.861491  0.852407  0.845348  0.839706
# 227  0.791246  0.849092  0.858924  0.849260  0.842021  0.836397  0.831901
# 258  0.241806  0.420586  0.538096  0.613618  0.670184  0.714136  0.749269
# 169  0.543795  0.654347  0.711424  0.739268  0.760123  0.776327  0.789280
# 0    0.524810  0.631362  0.686347  0.713151  0.733227  0.748826  0.761295
# 174  1.000000  1.000000  0.960466  0.912640  0.876818  0.848985  0.826736
# 79   0.483552  0.596569  0.657780  0.689706  0.713618  0.732198  0.747051
# 107  0.505686  0.613405  0.669975  0.698262  0.719449  0.735911  0.749070
# 223  0.426324  0.549285  0.619825  0.659332  0.688923  0.711914  0.730293
# 168  0.433963  0.555099  0.624040  0.662292  0.690943  0.713205  0.731000
# 155  0.423557  0.545932  0.616165  0.655519  0.684995  0.707898  0.726205
# 181  0.220949  0.387220  0.496663  0.567089  0.619839  0.660825  0.693587
# 130  0.465032  0.577127  0.638415  0.670777  0.695017  0.713851  0.728907
#
#          2033      2034      2035
# 218  1.000000  1.000000  1.000000
# 303  0.917129  0.913577  0.910573
# 156  0.871689  0.879000  0.885183
# 311  0.869590  0.876122  0.881647
# 117  0.854465  0.864581  0.873136
# 161  0.839803  0.846855  0.852820
# 100  0.836869  0.844747  0.851410
# 220  0.835093  0.831250  0.828000
# 227  0.828224  0.825163  0.822573
# 258  0.777996  0.801922  0.822158
# 169  0.799872  0.808693  0.816154
# 0    0.771490  0.779982  0.787164
# 174  0.808544  0.793393  0.780578
# 79   0.759194  0.769309  0.777864
# 107  0.759830  0.768791  0.776371
# 223  0.745320  0.757836  0.768422
# 168  0.745551  0.757669  0.767919
# 155  0.741174  0.753642  0.764187
# 181  0.720376  0.742688  0.761559
# 130  0.741217  0.751470  0.760141

# %%
future_com_hub_score_scaled.to_csv('../data/future_com_hub_score_scaled.csv')

# %% [markdown]
# # Accessibility Score PCA

# %%
acc_data = pd.read_csv("../data/final_combined_acc_v2.csv", index_col = 0)
inverse_cols = [col for col in acc_data.columns if col.endswith("to_mrt") or col.endswith("_Interval")]
acc_data[inverse_cols] = -acc_data[inverse_cols]
acc_data.head()
# Out:
#       subzone_name subzone_code  \
# 0        ADMIRALTY       SBSZ05
# 1     AIRPORT ROAD       PLSZ04
# 2   ALEXANDRA HILL       BMSZ07
# 3  ALEXANDRA NORTH       BMSZ06
# 4         ALJUNIED       GLSZ04
#
#                                        geog_boundary planning_area_name  \
# 0  POLYGON Z ((103.828545450459 1.45877524953475 ...          SEMBAWANG
# 1  POLYGON Z ((103.901327898145 1.35658812288024 ...         PAYA LEBAR
# 2  POLYGON Z ((103.81444653879 1.28547429883476 0...        BUKIT MERAH
# 3  POLYGON Z ((103.817404504805 1.29433192068692 ...        BUKIT MERAH
# 4  POLYGON Z ((103.891267385312 1.32131770982548 ...            GEYLANG
#
#        area  priv_to_public_ratio  total_bus_tap_in_volume  \
# 0  1.270958              0.623183            137532.182430
# 1  0.486377              0.438736             46088.367695
# 2  1.037840              0.313048            408694.021923
# 3  0.295823              0.258394            166908.374821
# 4  2.982971              0.518057            518701.385040
#
#    total_bus_tap_out_volume  total_buses_per_hour  num_bus_stops  ...  \
# 0             171045.739431            209.782652      16.522966  ...
# 1              46152.104231             63.222531       6.168052  ...
# 2             499763.616300            472.013995      23.124952  ...
# 3             135139.375783            274.234949      13.521600  ...
# 4             534555.599716            445.487025      15.085630  ...
#
#    fare_from_east region_to_mrt  duration_from_north-east region_to_mrt  \
# 0                     -2.464000                            -4866.400000
# 1                     -2.464000                            -4866.400000
# 2                     -2.464000                            -4866.400000
# 3                     -2.464000                            -4866.400000
# 4                     -1.683333                            -2465.333333
#
#    walking_dist_from_north-east region_to_mrt  \
# 0                                -1791.491000
# 1                                -1791.491000
# 2                                -1791.491000
# 3                                -1791.491000
# 4                                -1133.783333
#
#    fare_from_north-east region_to_mrt  duration_from_north region_to_mrt  \
# 0                           -2.360000                            -6217.2
# 1                           -2.360000                            -6217.2
# 2                           -2.360000                            -6217.2
# 3                           -2.360000                            -6217.2
# 4                           -1.836667                            -4263.0
#
#    walking_dist_from_north region_to_mrt  fare_from_north region_to_mrt  \
# 0                           -1662.159000                          -2.47
# 1                           -1662.159000                          -2.47
# 2                           -1662.159000                          -2.47
# 3                           -1662.159000                          -2.47
# 4                           -1240.456667                          -2.25
#
#    duration_from_west region_to_mrt  walking_dist_from_west region_to_mrt  \
# 0                      -5385.108333                             -2116.052
# 1                      -5385.108333                             -2116.052
# 2                      -5385.108333                             -2116.052
# 3                      -5385.108333                             -2116.052
# 4                      -3973.666667                             -1229.460
#
#    fare_from_west region_to_mrt
# 0                      -2.38973
# 1                      -2.38973
# 2                      -2.38973
# 3                      -2.38973
# 4                      -2.15000
#
# [5 rows x 40 columns]

# %%
acc_var = acc_data.iloc[:, 5:]
acc_bus_df = acc_var.iloc[:,1:15]
acc_mrt_df = acc_var.iloc[:,15:]

scaler = StandardScaler()
acc_norm = scaler.fit_transform(acc_var)
acc_bus = scaler.fit_transform(acc_bus_df)
acc_mrt = scaler.fit_transform(acc_mrt_df)

# %%
acc_pca = PCA()
acc_pca.fit(acc_norm)

transformed_data = acc_pca.transform(acc_norm)
explained_variance_ratio = acc_pca.explained_variance_ratio_

print(f"Explained variance ratio:{explained_variance_ratio}")
"""
pca components multiplied by the square root of the explained variance ratio
square root applied to scale loadings based on how much variance each principal component explains, which makes loadings more representative of 
variance captured by each component

"""
def get_weights(model, n_com):
    component_loadings = model.components_.T * np.sqrt(model.explained_variance_ratio_)
    component_loadings = component_loadings[:, :n_com]
    weights = np.sum(np.abs(component_loadings), axis = 1, keepdims = True)
    weights = weights.reshape(1,-1)
    return weights

weights = get_weights(acc_pca, 6) # used first 6 principal component for weights

print(f"Weights derived for Accessibility Score:{weights}")

weighted_df = acc_norm * weights[:,0] 
acc_data["acc_score"] = weighted_df.sum(axis = 1)

scaler = MinMaxScaler(feature_range=(0, 1))

# Fit and transform the accessibility_index column
acc_data["acc_score_scaled"] = scaler.fit_transform(acc_data[["acc_score"]])


acc_bus_pca = PCA()
acc_bus_pca.fit(acc_bus)
acc_bus_transformed = acc_bus_pca.transform(acc_bus)
acc_bus_weights = get_weights(acc_bus_pca, 3)
bus_weighted_df = acc_bus * acc_bus_weights[:1]
acc_data["bus_acc_score"] = bus_weighted_df.sum(axis = 1)

acc_data["bus_acc_score_scaled"] = scaler.fit_transform(acc_data[["bus_acc_score"]])

acc_mrt_pca = PCA()
acc_mrt_pca.fit(acc_mrt)
acc_mrt_transformed = acc_mrt_pca.transform(acc_mrt)
acc_mrt_weights = get_weights(acc_mrt_pca, 3)
mrt_weighted_df = acc_mrt * acc_mrt_weights[:1]
acc_data["mrt_acc_score"] = mrt_weighted_df.sum(axis = 1)

acc_data["mrt_acc_score_scaled"] = scaler.fit_transform(acc_data[["mrt_acc_score"]])
# Out:
# Explained variance ratio:[3.88804575e-01 1.71936910e-01 1.12561166e-01 7.20426103e-02
#  4.78609594e-02 3.25500254e-02 2.60211967e-02 2.01259678e-02
#  1.92581084e-02 1.54807672e-02 1.49390755e-02 1.04340415e-02
#  9.63036276e-03 8.34928475e-03 7.76821521e-03 7.24518931e-03
#  6.31395545e-03 5.18065422e-03 3.12421636e-03 2.73423369e-03
#  2.64668609e-03 2.28540137e-03 2.22157359e-03 1.93709427e-03
#  1.72447469e-03 1.38520370e-03 1.16263036e-03 1.00488009e-03
#  7.58359754e-04 7.39721164e-04 5.27931246e-04 4.97707486e-04
#  4.55525807e-04 2.79941417e-04 1.13548236e-05]
# Weights derived for Accessibility Score:[[0.26330444 0.30897626 0.31282635 0.35492568 0.30709319 0.30332227
#   0.28467666 0.23054231 0.19131138 0.25297678 0.23402324 0.23174644
#   0.21500253 0.22958139 0.23628615 0.31200891 0.31295261 0.29851284
#   0.31536318 0.31321624 0.30304193 0.22920594 0.30530691 0.24234323
#   0.24281616 0.22858513 0.24582088 0.2281209  0.24576402 0.28292812
#   0.23440595 0.31967826 0.32578075 0.22766817 0.33055946]]

# %% [markdown]
# ### Scree Plots

# %%
explained_var = acc_pca.explained_variance_ratio_
cumulative_var = np.cumsum(acc_pca.explained_variance_ratio_)

plt.figure(figsize=(10, 6))
plt.plot(range(1, len(explained_var)+1), explained_var, marker='o', linestyle='-', label='Individual Explained Variance')
plt.plot(range(1, len(cumulative_var)+1), cumulative_var, marker='o', linestyle='--', color='orange', label='Cumulative Explained Variance')
plt.axhline(y=0.8, color='red', linestyle='--', linewidth=1, label='80% Cumulative Variance')
plt.title('Scree Plot: Overall Accessibility PCA')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.xticks(range(1, len(explained_var)+1))
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
explained_var = acc_bus_pca.explained_variance_ratio_
cumulative_var = np.cumsum(acc_bus_pca.explained_variance_ratio_)

plt.figure(figsize=(10, 6))
plt.plot(range(1, len(explained_var)+1), explained_var, marker='o', linestyle='-', label='Individual Explained Variance')
plt.plot(range(1, len(cumulative_var)+1), cumulative_var, marker='o', linestyle='--', color='orange', label='Cumulative Explained Variance')
plt.axhline(y=0.8, color='red', linestyle='--', linewidth=1, label='80% Cumulative Variance')
plt.title('Scree Plot: Bus Accessibility PCA')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.xticks(range(1, len(explained_var)+1))
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
explained_var = acc_mrt_pca.explained_variance_ratio_
cumulative_var = np.cumsum(acc_mrt_pca.explained_variance_ratio_)

plt.figure(figsize=(10, 6))
plt.plot(range(1, len(explained_var)+1), explained_var, marker='o', linestyle='-', label='Individual Explained Variance')
plt.plot(range(1, len(cumulative_var)+1), cumulative_var, marker='o', linestyle='--', color='orange', label='Cumulative Explained Variance')

plt.axhline(y=0.8, color='red', linestyle='--', linewidth=1, label='80% Cumulative Variance')
plt.title('Scree Plot: Train Accessibility PCA')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.xticks(range(1, len(explained_var)+1))
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Final Weights

# %%
acc_coefficient_dict = dict(zip(acc_var.columns, weights[0,:])) 
acc_coefficient_dict
# Out:
# {'priv_to_public_ratio': 0.2633044407394113,
#  'total_bus_tap_in_volume': 0.308976257570797,
#  'total_bus_tap_out_volume': 0.312826347448812,
#  'total_buses_per_hour': 0.35492567901970323,
#  'num_bus_stops': 0.3070931878720984,
#  'num_bus_services': 0.30332227138296597,
#  'mean_bus_distance': 0.284676660470375,
#  'AM_Peak_Min_Interval': 0.23054231369662376,
#  'AM_Peak_Max_Interval': 0.19131137537496146,
#  'AM_Offpeak_Min_Interval': 0.25297678363013776,
#  'AM_Offpeak_Max_Interval': 0.23402324374351582,
#  'PM_Peak_Min_Interval': 0.23174643680114207,
#  'PM_Peak_Max_Interval': 0.21500252788110658,
#  'PM_Offpeak_Min_Interval': 0.22958139182985582,
#  'PM_Offpeak_Max_Interval': 0.23628615398688416,
#  'num_stations_per_subzone': 0.31200890783066604,
#  'num_train_lines_per_subzone': 0.3129526076113623,
#  'num_rail_types_per_subzone': 0.2985128375217616,
#  'total_train_tap_in_volume': 0.3153631805771824,
#  'total_train_tap_out_volume': 0.31321624276446525,
#  'duration_from_central region_to_mrt': 0.30304193242591876,
#  'walking_dist_from_central region_to_mrt': 0.22920593679122253,
#  'fare_from_central region_to_mrt': 0.3053069129074669,
#  'duration_from_east region_to_mrt': 0.24234323376647401,
#  'walking_dist_from_east region_to_mrt': 0.2428161636426926,
#  'fare_from_east region_to_mrt': 0.22858513440092004,
#  'duration_from_north-east region_to_mrt': 0.2458208758605678,
#  'walking_dist_from_north-east region_to_mrt': 0.22812090062270518,
#  'fare_from_north-east region_to_mrt': 0.24576401915285695,
#  'duration_from_north region_to_mrt': 0.28292812051469446,
#  'walking_dist_from_north region_to_mrt': 0.2344059460585353,
#  'fare_from_north region_to_mrt': 0.31967825622273605,
#  'duration_from_west region_to_mrt': 0.3257807494444836,
#  'walking_dist_from_west region_to_mrt': 0.22766817341153744,
#  'fare_from_west region_to_mrt': 0.3305594609008261}

# %%
bus_coefficient_dict = dict(zip(acc_bus_df.columns, acc_bus_weights[0,:]))
bus_coefficient_dict
# Out:
# {'total_bus_tap_in_volume': 0.2833130713748396,
#  'total_bus_tap_out_volume': 0.29210294707357976,
#  'total_buses_per_hour': 0.3090699498301439,
#  'num_bus_stops': 0.29630954736728815,
#  'num_bus_services': 0.28678480338453044,
#  'mean_bus_distance': 0.3052119983534269,
#  'AM_Peak_Min_Interval': 0.29775454715313504,
#  'AM_Peak_Max_Interval': 0.2647990002239865,
#  'AM_Offpeak_Min_Interval': 0.31037297387888024,
#  'AM_Offpeak_Max_Interval': 0.2884577495495341,
#  'PM_Peak_Min_Interval': 0.2944055537791692,
#  'PM_Peak_Max_Interval': 0.25082735500746056,
#  'PM_Offpeak_Min_Interval': 0.27021949918868093,
#  'PM_Offpeak_Max_Interval': 0.32081043107644047}

# %%
mrt_coefficient_dict = dict(zip(acc_mrt_df.columns, acc_mrt_weights[0,:]))
mrt_coefficient_dict
# Out:
# {'num_stations_per_subzone': 0.32753855240657653,
#  'num_train_lines_per_subzone': 0.32292071501913894,
#  'num_rail_types_per_subzone': 0.3173996503704438,
#  'total_train_tap_in_volume': 0.3222857666059738,
#  'total_train_tap_out_volume': 0.319298168008847,
#  'duration_from_central region_to_mrt': 0.29126864830407384,
#  'walking_dist_from_central region_to_mrt': 0.25787505237106584,
#  'fare_from_central region_to_mrt': 0.2909171317635554,
#  'duration_from_east region_to_mrt': 0.24543583862685095,
#  'walking_dist_from_east region_to_mrt': 0.27335517126001757,
#  'fare_from_east region_to_mrt': 0.24170351036978682,
#  'duration_from_north-east region_to_mrt': 0.2785399697078476,
#  'walking_dist_from_north-east region_to_mrt': 0.2630250895474026,
#  'fare_from_north-east region_to_mrt': 0.2706389510034829,
#  'duration_from_north region_to_mrt': 0.31335734454948727,
#  'walking_dist_from_north region_to_mrt': 0.2691170493792196,
#  'fare_from_north region_to_mrt': 0.34200693312610975,
#  'duration_from_west region_to_mrt': 0.306382739252874,
#  'walking_dist_from_west region_to_mrt': 0.2532546981779863,
#  'fare_from_west region_to_mrt': 0.2882554549306634}

# %%
acc_data.head()
# Out:
#       subzone_name subzone_code  \
# 0        ADMIRALTY       SBSZ05
# 1     AIRPORT ROAD       PLSZ04
# 2   ALEXANDRA HILL       BMSZ07
# 3  ALEXANDRA NORTH       BMSZ06
# 4         ALJUNIED       GLSZ04
#
#                                        geog_boundary planning_area_name  \
# 0  POLYGON Z ((103.828545450459 1.45877524953475 ...          SEMBAWANG
# 1  POLYGON Z ((103.901327898145 1.35658812288024 ...         PAYA LEBAR
# 2  POLYGON Z ((103.81444653879 1.28547429883476 0...        BUKIT MERAH
# 3  POLYGON Z ((103.817404504805 1.29433192068692 ...        BUKIT MERAH
# 4  POLYGON Z ((103.891267385312 1.32131770982548 ...            GEYLANG
#
#        area  priv_to_public_ratio  total_bus_tap_in_volume  \
# 0  1.270958              0.623183            137532.182430
# 1  0.486377              0.438736             46088.367695
# 2  1.037840              0.313048            408694.021923
# 3  0.295823              0.258394            166908.374821
# 4  2.982971              0.518057            518701.385040
#
#    total_bus_tap_out_volume  total_buses_per_hour  num_bus_stops  ...  \
# 0             171045.739431            209.782652      16.522966  ...
# 1              46152.104231             63.222531       6.168052  ...
# 2             499763.616300            472.013995      23.124952  ...
# 3             135139.375783            274.234949      13.521600  ...
# 4             534555.599716            445.487025      15.085630  ...
#
#    fare_from_north region_to_mrt  duration_from_west region_to_mrt  \
# 0                          -2.47                      -5385.108333
# 1                          -2.47                      -5385.108333
# 2                          -2.47                      -5385.108333
# 3                          -2.47                      -5385.108333
# 4                          -2.25                      -3973.666667
#
#    walking_dist_from_west region_to_mrt  fare_from_west region_to_mrt  \
# 0                             -2116.052                      -2.38973
# 1                             -2116.052                      -2.38973
# 2                             -2116.052                      -2.38973
# 3                             -2116.052                      -2.38973
# 4                             -1229.460                      -2.15000
#
#    acc_score  acc_score_scaled  bus_acc_score  bus_acc_score_scaled  \
# 0  -3.851919          0.198458      -1.199712              0.498751
# 1  -7.398542          0.086696      -4.567581              0.304022
# 2  -2.026905          0.255968       1.729860              0.668138
# 3  -3.423160          0.211969       0.319519              0.586593
# 4   4.483713          0.461131       1.023729              0.627310
#
#    mrt_acc_score  mrt_acc_score_scaled
# 0      -3.497001              0.000000
# 1      -3.497001              0.000000
# 2      -3.497001              0.000000
# 3      -3.497001              0.000000
# 4       3.460763              0.303348
#
# [5 rows x 46 columns]

# %%
# Convert dictionary to DataFrame for easy plotting
acc_weights_df = pd.DataFrame(list(acc_coefficient_dict.items()), columns=["Feature", "Weight"])
acc_weights_df = acc_weights_df.sort_values(by="Weight", ascending=True) # sort by weight

# Scatter Plot of PCA Weights
plt.figure(figsize=(10, 6))
sns.scatterplot(x="Weight", y="Feature", data = acc_weights_df, hue="Weight", palette="coolwarm", size=5, legend=False)

plt.axvline(x=0, color="black", linestyle="--", alpha=0.6)
plt.title("PCA-Derived Weights (Accessibility Score)", fontsize=14)
plt.xlabel("Weight", fontsize=12)
plt.ylabel("Feature", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.5)

plt.show()

# %% [markdown]
# ## Accessibililty Score of PT across hours in a day

# %%
hourly_data = pd.read_csv("../data/pt_hourly.csv", index_col = 0)
#limit to nearest year_month
hourly_data = hourly_data[(hourly_data['YEAR_MONTH']=='2025-01')]

hourly_var = hourly_data.iloc[:,3:]
            
scaler = StandardScaler()
hourly_norm = scaler.fit_transform(hourly_var)

hourly_pca = PCA()
hourly_pca.fit(hourly_norm)

hourly_weights = get_weights(hourly_pca, 1)
hourly_weighted_df = hourly_var * hourly_weights[:1]
hourly_data["acc_score"] = hourly_weighted_df.sum(axis = 1)

# scale acc score to range (0,1)
scaler = MinMaxScaler(feature_range=(0, 1))
hourly_data["acc_score_scaled"] = scaler.fit_transform(hourly_data[["acc_score"]])

hourly_data[(hourly_data['subzone_name']=='RAFFLES PLACE')].head()
# Out:
#       subzone_name  hour YEAR_MONTH  total_bus_trips_inbound  \
# 290  RAFFLES PLACE     0    2025-01                 2.333333
# 293  RAFFLES PLACE     1    2025-01                 0.000000
# 296  RAFFLES PLACE     2    2025-01                 0.000000
# 299  RAFFLES PLACE     3    2025-01                 0.000000
# 302  RAFFLES PLACE     4    2025-01                 0.000000
#
#      total_bus_trips_outbound  total_train_trips_inbound  \
# 290                   4.49375                   2.142857
# 293                   0.00000                   0.000000
# 296                   0.00000                   0.000000
# 299                   0.00000                   0.000000
# 302                   0.00000                   0.000000
#
#      total_train_trips_outbound  acc_score  acc_score_scaled
# 290                    8.863248   6.888899          0.011996
# 293                    0.000000   0.000000          0.000000
# 296                    0.000000   0.000000          0.000000
# 299                    0.000000   0.000000          0.000000
# 302                    0.000000   0.000000          0.000000

# %% [markdown]
# ## Projection Function for Acc Score

# %%
subzone = pd.read_csv("../data/subzone_final.csv", index_col = 0)
subzone = subzone[["subzone_name","geog_boundary"]]
subzone = gpd.GeoDataFrame(subzone, geometry=gpd.GeoSeries.from_wkt(subzone["geog_boundary"]), crs="EPSG:4326") 
subzone.head()
# Out:
#     subzone_name                                      geog_boundary  \
# 0     DEPOT ROAD  POLYGON Z ((103.814542206408 1.28238675809122 ...
# 1    BUKIT MERAH  POLYGON Z ((103.822087677142 1.28049448959193 ...
# 2      CHINATOWN  POLYGON Z ((103.843752427547 1.28507938173851 ...
# 3        PHILLIP  POLYGON Z ((103.849619049458 1.28411912067044 ...
# 4  RAFFLES PLACE  POLYGON Z ((103.85252728092 1.28616568617335 0...
#
#                                             geometry
# 0  POLYGON Z ((103.81454 1.28239 0, 103.81774 1.2...
# 1  POLYGON Z ((103.82209 1.28049 0, 103.8221 1.28...
# 2  POLYGON Z ((103.84375 1.28508 0, 103.844 1.284...
# 3  POLYGON Z ((103.84962 1.28412 0, 103.84955 1.2...
# 4  POLYGON Z ((103.85253 1.28617 0, 103.85253 1.2...

# %%
# retrieve acc data before normalisation
prenorm_data = pd.read_csv("../data/final_combined_acc.csv", index_col = 0)
prenorm_data[inverse_cols] = -prenorm_data[inverse_cols]
prenorm_var = prenorm_data.iloc[:, 4:]
prenorm_data.shape
# Out:
# (315, 40)

# %%
# prepare another set of post-preprocessed data for creation of scaler to be used in function

columns_to_normalize_acc = [
    "num_bus_stops","num_bus_services",
    "num_stations_per_subzone", "num_train_lines_per_subzone",
    "num_rail_types_per_subzone","total_bus_tap_in_volume","total_bus_tap_out_volume",
    "total_buses_per_hour","total_train_tap_in_volume","total_train_tap_out_volume"
]

# Perform element-wise division by 'area', avoiding division by zero
prenorm_var[columns_to_normalize_acc] = prenorm_var[columns_to_normalize_acc].div(prenorm_var["area"], axis=0)
prenorm_var.drop(columns=["area"], inplace = True)

#create pre-fit scaler
f_scaler = StandardScaler().fit(prenorm_var)

# %%
# user can input lat, lng and num of bus/train stations to vary to imagine how it would change when new bus stop or train station is added
def get_projected_score(lat,lng, n_bus_diff, n_train_diff, df, scaler, weights_dict):
    plc = gpd.GeoDataFrame(geometry=[Point(lng, lat)], crs="EPSG:4326") 
    subzone_match = gpd.sjoin(plc, subzone, how="inner", predicate="within")
    if subzone_match.empty:
        return None
    subzone_name = subzone_match.iloc[0]["subzone_name"]
    data = df.loc[df["subzone_name"] == subzone_name]
    # make a copy
    var = data.iloc[:, 5:].copy()
    
    # retrieve indices for bus and train columns before amending the values
    bus_ind = var.columns.get_loc("num_bus_stops")
    train_ind = var.columns.get_loc("num_stations_per_subzone")
    var.iloc[0, bus_ind] = max(var.iloc[0, bus_ind] + n_bus_diff, 0)
    var.iloc[0, train_ind] = max(var.iloc[0, train_ind] + n_train_diff, 0)

    # highlight the columns to normalise by area
    columns_to_normalize = [
    "num_bus_stops","num_bus_services",
    "num_stations_per_subzone", "num_train_lines_per_subzone",
    "num_rail_types_per_subzone","total_bus_tap_in_volume","total_bus_tap_out_volume",
    "total_buses_per_hour","total_train_tap_in_volume","total_train_tap_out_volume"
    ]

    # Perform element-wise division by 'area', avoiding division by zero
    var[columns_to_normalize] = var[columns_to_normalize].div(data["area"], axis=0)
    col_names = var.columns.tolist()
    
    # Scale values based on pre-fit scaler
    var = scaler.transform(var)
    var = pd.DataFrame(var, columns = col_names)
    
    # Extract weights from dict
    weights = np.array([weights_dict[col] for col in var.columns])

    # Apply weights to find the new acc score with different no of train stations and bus stops
    new_acc_score = np.dot(weights, var.values.flatten())

    return new_acc_score

# %%
# Test projected score function

# Dummy location below falls within Admiralty subzone
lat = 1.458  # Latitude of the location
lng = 103.8285  # Longitude of the location
n_bus_diff = 2  # Increase in the number of bus stations
n_train_diff = 1  # Increase in the number of train stations

# Calculate the projected score
score = get_projected_score(lat, lng, n_bus_diff, n_train_diff, prenorm_data, f_scaler, acc_coefficient_dict)
if score is not None:
    print("Projected Accessibility Score:", score)
else:
    print("The provided coordinates do not fall within any subzone.")

# To obtain scaled value of new accessibility score
scaler = MinMaxScaler(feature_range=(0, 1))

# Fit the scaler to the existing accessibility scores
scaler.fit(acc_data[["acc_score"]])
new_acc_score_scaled = scaler.transform([[score]])[0][0]
print("Scaled Projected Accessibility Score:", new_acc_score_scaled)

# original scaled acc score = 0.19845795830063800
# Out:
# Projected Accessibility Score: -3.7868059961632876
# Scaled Projected Accessibility Score: 0.20050981334920287
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
# Test projected score function

# Dummy location below falls within Airport Road subzone
lat = 1.3565  # Latitude of the location
lng = 103.9013  # Longitude of the location
n_bus_diff = 3  # Increase in the number of bus stations
n_train_diff = 1  # Increase in the number of train stations

# Calculate the projected score
score = get_projected_score(lat, lng, n_bus_diff, n_train_diff, prenorm_data, f_scaler, acc_coefficient_dict)
if score is not None:
    print("Projected Accessibility Score:", score)
else:
    print("The provided coordinates do not fall within any subzone.")

# To obtain scaled value of new accessibility score
scaler = MinMaxScaler(feature_range=(0, 1))

# Fit the scaler to the existing accessibility scores
scaler.fit(acc_data[["acc_score"]])
new_acc_score_scaled = scaler.transform([[score]])[0][0]
print("Scaled Projected Accessibility Score:", new_acc_score_scaled)

# original scaled acc score = 0.08669645520119980
# Out:
# Projected Accessibility Score: -6.8582221951447835
# Scaled Projected Accessibility Score: 0.10372306978199566
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## EDA for Accessibility Score

# %%
# Aggregate by planning area
planning_agg = acc_data.groupby(["planning_area_name"]).agg(
    mean_access = ("acc_score_scaled", "mean"),
    mean_access_bus = ("bus_acc_score_scaled", "mean"),
    mean_access_mrt = ("mrt_acc_score_scaled", "mean")
).reset_index()
planning_agg.sort_values(by="mean_access", ascending=False).head(50)
# Out:
#          planning_area_name  mean_access  mean_access_bus  mean_access_mrt
# 27                   OUTRAM     0.571065         0.706488         0.466334
# 23                   MUSEUM     0.545380         0.692016         0.411378
# 18                  KALLANG     0.450682         0.639480         0.291004
# 34                   ROCHOR     0.441963         0.688604         0.266553
# 2                    BISHAN     0.433865         0.642030         0.258750
# 14                  GEYLANG     0.425808         0.615301         0.261784
# 6             BUKIT PANJANG     0.416917         0.631789         0.249095
# 33             RIVER VALLEY     0.409209         0.543193         0.326350
# 7               BUKIT TIMAH     0.395363         0.624690         0.223413
# 1                     BEDOK     0.392994         0.554042         0.254165
# 26                  ORCHARD     0.377328         0.529934         0.269960
# 43                 TAMPINES     0.373766         0.548976         0.223634
# 37                 SENGKANG     0.368053         0.455260         0.296694
# 46                TOA PAYOH     0.365226         0.671430         0.134918
# 32               QUEENSTOWN     0.353102         0.606841         0.175901
# 11            CHOA CHU KANG     0.350607         0.606477         0.154037
# 49                WOODLANDS     0.335147         0.586923         0.152224
# 13            DOWNTOWN CORE     0.332972         0.438265         0.287706
# 4               BUKIT BATOK     0.332458         0.608748         0.132724
# 5               BUKIT MERAH     0.331958         0.645811         0.124873
# 39          SINGAPORE RIVER     0.331703         0.618230         0.161829
# 44                  TANGLIN     0.328517         0.571684         0.173835
# 38                SERANGOON     0.328269         0.637672         0.116038
# 31                  PUNGGOL     0.326323         0.413889         0.261712
# 15                  HOUGANG     0.316364         0.604697         0.113452
# 0                ANG MO KIO     0.298964         0.562856         0.124843
# 30                  PIONEER     0.288023         0.601467         0.074806
# 25                   NOVENA     0.276794         0.588677         0.080821
# 24                   NEWTON     0.276192         0.532945         0.134280
# 17              JURONG WEST     0.273604         0.596137         0.057280
# 50                   YISHUN     0.272597         0.520653         0.109012
# 28                PASIR RIS     0.272586         0.613114         0.037022
# 9                    CHANGI     0.270927         0.550763         0.081832
# 12                 CLEMENTI     0.268766         0.625877         0.037754
# 16              JURONG EAST     0.266691         0.575778         0.070457
# 10               CHANGI BAY     0.264533         0.672427         0.000000
# 36                SEMBAWANG     0.235127         0.486787         0.069612
# 42             SUNGEI KADUT     0.230990         0.531741         0.042814
# 29               PAYA LEBAR     0.219885         0.575046         0.000000
# 47                     TUAS     0.202834         0.431843         0.072601
# 3                  BOON LAY     0.196081         0.528397         0.000000
# 22            MARINE PARADE     0.193527         0.362075         0.126256
# 48  WESTERN WATER CATCHMENT     0.193448         0.514265         0.000000
# 40         SOUTHERN ISLANDS     0.180714         0.516651         0.000000
# 41             STRAITS VIEW     0.168519         0.000190         0.369218
# 20                   MANDAI     0.160137         0.443598         0.000000
# 19             LIM CHU KANG     0.147427         0.427262         0.000000
# 45                   TENGAH     0.144159         0.415715         0.000000
# 35                  SELETAR     0.134344         0.400997         0.000000
# 8   CENTRAL WATER CATCHMENT     0.101134         0.348709         0.000000

# %%
planning_agg.describe()
# Out:
#        mean_access  mean_access_bus  mean_access_mrt
# count    51.000000        51.000000        51.000000
# mean      0.299196         0.535420         0.147285
# std       0.106269         0.139961         0.120285
# min       0.085977         0.000000         0.000000
# 25%       0.225437         0.500526         0.050047
# 50%       0.298964         0.571684         0.126256
# 75%       0.366640         0.616766         0.251630
# max       0.571065         0.706488         0.466334

# %%
top_10 = planning_agg.nlargest(10, "mean_access")
bottom_10 = planning_agg.nsmallest(10, "mean_access")
fig, ax = plt.subplots(1, 2, figsize=(18, 5))

# Top 10 planning areas
sns.barplot(y="planning_area_name", x="mean_access", data=top_10, ax=ax[0], palette="Greens_r")
ax[0].set_title("Top 10 Planning Areas by Total Accessibility")
ax[0].set_xlabel("Mean Accessibility Score")
ax[0].set_ylabel("Planning Area")

# Bottom 10 planning areas
sns.barplot(y="planning_area_name", x="mean_access", data=bottom_10, ax=ax[1], palette="Reds_r")
ax[1].set_title("Bottom 10 Planning Areas by Total Accessibility")
ax[1].set_xlabel("Mean Accessibility Score")
ax[1].set_ylabel("Planning Area")

plt.subplots_adjust(wspace=0.5)
# Out:
# /var/folders/yj/8qrtgn4s6kb6mhh8f09ypm5r0000gn/T/ipykernel_42798/3188704121.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="planning_area_name", x="mean_access", data=top_10, ax=ax[0], palette="Greens_r")
# /var/folders/yj/8qrtgn4s6kb6mhh8f09ypm5r0000gn/T/ipykernel_42798/3188704121.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="planning_area_name", x="mean_access", data=bottom_10, ax=ax[1], palette="Reds_r")

# %%
top_10 = planning_agg.nlargest(10, "mean_access_bus")
bottom_10 = planning_agg.nsmallest(10, "mean_access_bus")
fig, ax = plt.subplots(1, 2, figsize=(18, 5))

# Top 10 planning areas
sns.barplot(y="planning_area_name", x="mean_access_bus", data=top_10, ax=ax[0], palette="Greens_r")
ax[0].set_title("Top 10 Planning Areas by Total Bus Accessibility")
ax[0].set_xlabel("Mean Accessibility Score")
ax[0].set_ylabel("Planning Area")

# Bottom 10 planning areas
sns.barplot(y="planning_area_name", x="mean_access_bus", data=bottom_10, ax=ax[1], palette="Reds_r")
ax[1].set_title("Bottom 10 Planning Areas by Total Bus Accessibility")
ax[1].set_xlabel("Mean Accessibility Score")
ax[1].set_ylabel("Planning Area")

plt.subplots_adjust(wspace=0.5)
# Out:
# /var/folders/yj/8qrtgn4s6kb6mhh8f09ypm5r0000gn/T/ipykernel_42798/3658852313.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="planning_area_name", x="mean_access_bus", data=top_10, ax=ax[0], palette="Greens_r")
# /var/folders/yj/8qrtgn4s6kb6mhh8f09ypm5r0000gn/T/ipykernel_42798/3658852313.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="planning_area_name", x="mean_access_bus", data=bottom_10, ax=ax[1], palette="Reds_r")

# %%
planning_agg.sort_values(by="mean_access_mrt", ascending=True)
# Out:
#          planning_area_name  mean_access  mean_access_bus  mean_access_mrt
# 19             LIM CHU KANG     0.147427         0.427262         0.000000
# 29               PAYA LEBAR     0.219885         0.575046         0.000000
# 35                  SELETAR     0.134344         0.400997         0.000000
# 10               CHANGI BAY     0.264533         0.672427         0.000000
# 20                   MANDAI     0.160137         0.443598         0.000000
# 40         SOUTHERN ISLANDS     0.180714         0.516651         0.000000
# 8   CENTRAL WATER CATCHMENT     0.101134         0.348709         0.000000
# 45                   TENGAH     0.144159         0.415715         0.000000
# 3                  BOON LAY     0.196081         0.528397         0.000000
# 48  WESTERN WATER CATCHMENT     0.193448         0.514265         0.000000
# 28                PASIR RIS     0.272586         0.613114         0.037022
# 12                 CLEMENTI     0.268766         0.625877         0.037754
# 42             SUNGEI KADUT     0.230990         0.531741         0.042814
# 17              JURONG WEST     0.273604         0.596137         0.057280
# 36                SEMBAWANG     0.235127         0.486787         0.069612
# 16              JURONG EAST     0.266691         0.575778         0.070457
# 47                     TUAS     0.202834         0.431843         0.072601
# 30                  PIONEER     0.288023         0.601467         0.074806
# 25                   NOVENA     0.276794         0.588677         0.080821
# 9                    CHANGI     0.270927         0.550763         0.081832
# 50                   YISHUN     0.272597         0.520653         0.109012
# 15                  HOUGANG     0.316364         0.604697         0.113452
# 38                SERANGOON     0.328269         0.637672         0.116038
# 0                ANG MO KIO     0.298964         0.562856         0.124843
# 5               BUKIT MERAH     0.331958         0.645811         0.124873
# 22            MARINE PARADE     0.193527         0.362075         0.126256
# 4               BUKIT BATOK     0.332458         0.608748         0.132724
# 24                   NEWTON     0.276192         0.532945         0.134280
# 46                TOA PAYOH     0.365226         0.671430         0.134918
# 49                WOODLANDS     0.335147         0.586923         0.152224
# 11            CHOA CHU KANG     0.350607         0.606477         0.154037
# 39          SINGAPORE RIVER     0.331703         0.618230         0.161829
# 44                  TANGLIN     0.328517         0.571684         0.173835
# 32               QUEENSTOWN     0.353102         0.606841         0.175901
# 7               BUKIT TIMAH     0.395363         0.624690         0.223413
# 43                 TAMPINES     0.373766         0.548976         0.223634
# 21             MARINA SOUTH     0.085977         0.000000         0.234589
# 6             BUKIT PANJANG     0.416917         0.631789         0.249095
# 1                     BEDOK     0.392994         0.554042         0.254165
# 2                    BISHAN     0.433865         0.642030         0.258750
# 31                  PUNGGOL     0.326323         0.413889         0.261712
# 14                  GEYLANG     0.425808         0.615301         0.261784
# 34                   ROCHOR     0.441963         0.688604         0.266553
# 26                  ORCHARD     0.377328         0.529934         0.269960
# 13            DOWNTOWN CORE     0.332972         0.438265         0.287706
# 18                  KALLANG     0.450682         0.639480         0.291004
# 37                 SENGKANG     0.368053         0.455260         0.296694
# 33             RIVER VALLEY     0.409209         0.543193         0.326350
# 41             STRAITS VIEW     0.168519         0.000190         0.369218
# 23                   MUSEUM     0.545380         0.692016         0.411378
# 27                   OUTRAM     0.571065         0.706488         0.466334

# %%
top_10 = planning_agg.nlargest(10, "mean_access_mrt")
bottom_10 = planning_agg.nsmallest(10, "mean_access_mrt")
fig, ax = plt.subplots(1, 2, figsize=(18, 5))

# Top 10 planning areas
sns.barplot(y="planning_area_name", x="mean_access_mrt", data=top_10, ax=ax[0], palette="Greens_r")
ax[0].set_title("Top 10 Planning Areas by Total Train Accessibility")
ax[0].set_xlabel("Mean Accessibility Score")
ax[0].set_ylabel("Planning Area")

# Bottom 10 planning areas
sns.barplot(y="planning_area_name", x="mean_access_mrt", data=bottom_10, ax=ax[1], palette="Reds_r")
ax[1].set_title("Bottom 10 Planning Areas by Total Train Accessibility")
ax[1].set_xlabel("Mean Accessibility Score")
ax[1].set_ylabel("Planning Area")

plt.subplots_adjust(wspace=0.5)
# Out:
# /var/folders/yj/8qrtgn4s6kb6mhh8f09ypm5r0000gn/T/ipykernel_42798/3261552957.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="planning_area_name", x="mean_access_mrt", data=top_10, ax=ax[0], palette="Greens_r")
# /var/folders/yj/8qrtgn4s6kb6mhh8f09ypm5r0000gn/T/ipykernel_42798/3261552957.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="planning_area_name", x="mean_access_mrt", data=bottom_10, ax=ax[1], palette="Reds_r")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=planning_agg[["mean_access", "mean_access_bus", "mean_access_mrt"]])
plt.title("Distribution of Accessibility Scores Across Planning Areas")
plt.ylabel("Accessibility Score")
plt.xticks([0, 1, 2], ["Overall Access", "Bus Access", "MRT Access"])
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()

# %%
acc_data.to_csv("../data/final_combined_acc_pca.csv")

# %%
hourly_data.to_csv("../data/hourly_data_pca.csv")
